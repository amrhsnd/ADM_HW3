# %% [markdown]
# <a href="https://colab.research.google.com/github/amrhsnd/ADM_HW3/blob/federico/ADM_HW3_point2_and_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# loade the file
file_path = '/content/output.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#    index     restaurantName                    address  \
# 0      1              20Tre   via David Chiossone 20 r
# 1      2     Alessandro Feo        via Angelo Lista 24
# 2      3  Ape Vino e Cucina      Piazza Risorgimento 3
# 3      4         Charleston  via Generale Magliocco 19
# 4      5   Da Bob Cook Fish   largo Parsano vecchio 16
#
#                       city  postalCode country priceRange  \
# 0                    Genoa       16123   Italy         €€
# 1   Marina di Casal Velino       84040   Italy         €€
# 2                     Alba       12051   Italy         €€
# 3                  Palermo       90141   Italy       €€€€
# 4                 Sorrento       80067   Italy         €€
#
#                      cuisineType  \
# 0  Farm to table, Modern Cuisine
# 1             Campanian, Seafood
# 2      Piedmontese, Contemporary
# 3       Modern Cuisine, Creative
# 4                        Seafood
#
#                                          description  \
# 0  Situated in the heart of Genoa’s historic cent...
# 1  In a beautiful stone-vaulted building (an old ...
# 2  This attractive restaurant in the heart of Alb...
# 3  Before it became famous in Mondello, the renow...
# 4  Working in partnership with the nearby fishmon...
#
#                                          creditCards  \
# 0       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 1       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 2  ['Amex', 'Dinersclub', 'Maestrocard', 'Masterc...
# 3                     ['Amex', 'Mastercard', 'Visa']
# 4       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
#
#                                   facilitiesServices        phoneNumber  \
# 0                               ['Air conditioning']   +39 010 247 6191
# 1                                                 []   +39 328 893 7083
# 2  ['Air conditioning', 'Terrace', 'Wheelchair ac...    +39 0173 363453
# 3  ['Air conditioning', 'Counter dining', 'Terrac...     +39 091 450171
# 4                    ['Air conditioning', 'Terrace']  +39 081 1778 3873
#
#                                    website
# 0    https://www.ristorante20tregenova.it/
# 1  https://www.alessandrofeoristorante.it/
# 2          https://www.apewinebar.it/alba/
# 3              https://casacharleston.net/
# 4           https://www.dabobcookfish.com/

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1983 entries, 0 to 1982
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               1983 non-null   int64
#  1   restaurantName      1983 non-null   object
#  2   address             1983 non-null   object
#  3   city                1983 non-null   object
#  4   postalCode          1983 non-null   int64
#  5   country             1983 non-null   object
#  6   priceRange          1983 non-null   object
#  7   cuisineType         1983 non-null   object
#  8   description         1983 non-null   object
#  9   creditCards         1983 non-null   object
#  10  facilitiesServices  1983 non-null   object
#  11  phoneNumber         1983 non-null   object
#  12  website             1983 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 201.5+ KB
# None

# %% [markdown]
# #**[2.0] Search Engine**

# %% [markdown]
# #### **Objective**:
# The goal of this step is to build an effective search engine to retrieve restaurants based on user queries. We implemented two types of search engines to address different needs: a **Conjunctive Search Engine** and a **Ranked Search Engine**.
#
# #### **Steps**:
#
# 2.0 **Preprocessing**
#
# 2.1 **Conjunctive Query Search Engine**
#
# 2.2 **Ranked Search Engine with TF-IDF and Cosine Similarity**
#
# #### **Output**:
# - For both search engines, the results include:
#   - `restaurantName`
#   - `address`
#   - `description`
#   - `cuisineType`
#   - `priceRange`
#   - `website`

# %% [markdown]
# ### 2.0 Preprocessing
#    - We start by cleaning and preparing the text data from restaurant descriptions to improve the search engine's accuracy.
#    - The preprocessing steps include:
#      - **Removing Stopwords**: Common words (e.g., "and," "the") that do not contribute to the search context are removed using the `nltk` library.
#      - **Removing Punctuation**: Punctuation marks are eliminated to focus purely on text content.
#      - **Stemming**: Words are reduced to their base form (e.g., "cooking" to "cook") using the Porter Stemmer from `nltk`, allowing better matching of terms.
#    - The cleaned and preprocessed text is stored in a new column called `processed_description`.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

# Download stopwords
nltk.download('stopwords')

def preprocess_text(text):
    stop_words = set(stopwords.words("english"))
    stemmer = PorterStemmer()

    # Convert text to lowercase and remove punctuation including quotes and numbers
    text = text.lower().translate(str.maketrans("", "", '‘[]’“”-1234567890' + string.punctuation))

    # Tokenize, remove stopwords and stem (and remove single-letter words)
    tokens = [stemmer.stem(word) for word in text.split() if word not in stop_words and len(word) > 1]

    return " ".join(tokens)

# Apply preprocessing to descriptions
data["processed_description"] = data["description"].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### 2.1 Conjunctive Query Search Engine
#    - This search engine narrows down the results by returning only those restaurants whose **descriptions contain all query terms**.
#    - We implemented an **Inverted Index** for efficient querying:
#      - **Vocabulary File**: It maps each unique word to a unique `term_id`.
#      - **Inverted Index**: A dictionary where each `term_id` points to a list of document IDs (restaurant entries) that contain the word.
#    - **Query Execution**:
#      - The user query is preprocessed similarly to the restaurant descriptions.
#      - The search engine retrieves documents (restaurants) that contain **all terms** from the user query.
#    - This method ensures precise matching, making it suitable for specific, multi-keyword searches.

# %%
from collections import defaultdict
#vocabulary and inverted index
vocabulary = {}
inverted_index = defaultdict(list)

term_id = 0

for idx, row in data.iterrows():
    description = row["processed_description"]
    restaurant_id = row["index"]

    for word in set(description.split()):  # Use set to avoid duplicates in one description
        if word not in vocabulary:
            vocabulary[word] = term_id
            term_id += 1

        term_id_for_word = vocabulary[word]
        inverted_index[term_id_for_word].append(restaurant_id)

# %%
import json

# Save vocabulary as vocabulary.csv
vocab_df = pd.DataFrame(list(vocabulary.items()), columns=["word", "term_id"])
vocab_df.to_csv("/content/vocabulary.csv", index=False)

# Save inverted index as inverted_index.json
with open("/content/inverted_index.json", "w") as f:
    json.dump(inverted_index, f)

# %% [markdown]
# 2.1.2

# %%
# Function to preprocess and execute the query
def execute_query(query, data):
    # Preprocess the query terms using the preprocess_text function
    processed_query = preprocess_text(query)
    query_terms = set(processed_query.split())

    # Find matching restaurants by checking if all query terms are in the processed description
    matched_restaurants = data[data["processed_description"].apply(lambda desc: query_terms.issubset(desc.split()))]

    # Select only the necessary columns for the output
    return matched_restaurants

# Prompt the user to input a query
query1 = 'modern seasonal cuisine'

result1 = execute_query(query1, data)

result1
# Out:
#       index                   restaurantName  \
# 24       25                  Casin del Gamba
# 98       99                      San Giorgio
# 186     187            Il Luogo Aimo e Nadia
# 211     212                       Vesta Mare
# 302     303                     Ca' Del Moro
# 323     324                        Contrasto
# 336     337                             Saur
# 416     417                      San Michele
# 446     447                        Chichibio
# 499     500           Winter Garden Florence
# 627     628                        Esplanade
# 631     632                         La Valle
# 699     700                        Zum Löwen
# 806     807           Degusteria del Gigante
# 891     892                      La Bandiera
# 916     917                      Pipero Roma
# 936     937                    Secondo Tempo
# 982     983                          Aprudia
# 1074   1075                     Piccolo Lord
# 1155   1156                        Ronchi Rò
# 1217   1218                            Razzo
# 1286   1287                           Flurin
# 1316   1317                   Quadri Bistrot
# 1329   1330          Materia | Spazio Cucina
# 1446   1447    Gallery Bistrot Contemporaneo
# 1540   1541                         [àbitat]
# 1544   1545                          Babette
# 1563   1564  Cappuccini Cucina San Francesco
# 1631   1632                    Osteria Ophis
# 1636   1637                          Sintesi
# 1674   1675                  Osteria Taviani
# 1697   1698                     Retrobottega
# 1734   1735                       RistoFante
# 1797   1798                         Radimare
# 1809   1810                  Locanda Solagna
# 1811   1812          Osteria del Miglio 2.10
# 1817   1818                             Savô
# 1848   1849                 Le Vie del Borgo
# 1898   1899                         Saporium
# 1909   1910                          Il Tino
# 1952   1953                             Mima
#
#                                        address                        city  \
# 24                       via Roccolo Pizzati 1                   Altissimo
# 98                   viale Brigate Bisagno 69r                       Genoa
# 186                         via Montecuccoli 6                       Milan
# 211                              viale Roma 41       Marina di Pietrasanta
# 302                          località Erbin 31                    Grezzana
# 323                                via Roma 55               Cercemaggiore
# 336                       via Filippo Turati 8                       Barco
# 416                 via Castello di Fagagna 33                     Fagagna
# 446                    via Guglielmo Marconi 1                   Roccaraso
# 499                        piazza Ognissanti 1                    Florence
# 627                                via Lario 3         Desenzano del Garda
# 631   via Umberto I 25, località Valle Sauglio                  Trofarello
# 699                              via Tirolo 25                      Tisens
# 806                        via degli Anelli 19    San Benedetto del Tronto
# 891                         contrada Pastini 4          Civitella Casanova
# 916             corso Vittorio Emanuele II 250                        Rome
# 936                     via Vittorio Amedeo 55             Termini Imerese
# 982                         largo del Forno 16                  Giulianova
# 1074               corso San Maurizio 69 bis/g                       Turin
# 1155               località Cime di Dolegna 12          Dolegna del Collio
# 1217                     via Andrea Doria 17/f                       Turin
# 1286                             Laubengasse 2                    Glorenza
# 1316                          Via Solferino 48                       Milan
# 1329                     via Teatro Massimo 29                     Catania
# 1446                 via Regina Margherita 3/b                       Troia
# 1540                        via Henry Dunant 1   San Fermo della Battaglia
# 1544                       via Michelangelo 17                     Albenga
# 1563                         via Cappuccini 54                     Cologne
# 1631                 corso Serpente Aureo 54/b                      Offida
# 1636                      viale dei Castani 17                     Ariccia
# 1674            piazza Vittorio Emanuele II 28                    Bientina
# 1697                     via della Stelletta 4                        Rome
# 1734                            via Mazzini 41             Alzano Lombardo
# 1797        via Beato Piergiorgio Frassati 5/a                    Monopoli
# 1809                      piazza I  Novembre 2                       Quero
# 1811                            via Patrioti 2           Pieve San Giacomo
# 1817                       piazza XXV Aprile 8                  Laigueglia
# 1848                         via alla Piazza 6                      Toceno
# 1898                   località Palazzetto 110                   Chiusdino
# 1909                      via Monte Cadria 127                   Fiumicino
# 1952                          via Madonnelle 9                Vico Equense
#
#       postalCode country priceRange  \
# 24         36070   Italy       €€€€
# 98         16129   Italy        €€€
# 186        20147   Italy       €€€€
# 211        55045   Italy        €€€
# 302        37023   Italy        €€€
# 323        86012   Italy         €€
# 336        25034   Italy         €€
# 416        33034   Italy         €€
# 446        67037   Italy         €€
# 499        50123   Italy       €€€€
# 627        25015   Italy       €€€€
# 631        10028   Italy        €€€
# 699        39010   Italy        €€€
# 806        63074   Italy         €€
# 891        65010   Italy        €€€
# 916          186   Italy       €€€€
# 936        90018   Italy        €€€
# 982        64021   Italy        €€€
# 1074       10124   Italy         €€
# 1155       34070   Italy         €€
# 1217       10123   Italy         €€
# 1286       39020   Italy         €€
# 1316       20121   Italy         €€
# 1329       95131   Italy         €€
# 1446       71029   Italy         €€
# 1540       22020   Italy        €€€
# 1544       17031   Italy         €€
# 1563       25033   Italy        €€€
# 1631       63073   Italy         €€
# 1636          72   Italy        €€€
# 1674       56031   Italy         €€
# 1697         186   Italy        €€€
# 1734       24022   Italy        €€€
# 1797       70043   Italy         €€
# 1809       32038   Italy         €€
# 1811       26035   Italy          €
# 1817       17053   Italy        €€€
# 1848       28858   Italy         €€
# 1898       53012   Italy       €€€€
# 1909          54   Italy        €€€
# 1952       80069   Italy         €€
#
#                                       cuisineType  \
# 24                Country cooking, Modern Cuisine
# 98                       Modern Cuisine, Ligurian
# 186          Italian Contemporary, Modern Cuisine
# 211                      Seafood, Classic Cuisine
# 302   Italian Contemporary, Mediterranean Cuisine
# 323                      Modern Cuisine, Creative
# 336                          Italian Contemporary
# 416                                Modern Cuisine
# 446          Modern Cuisine, Cuisine from Abruzzo
# 499                         Mediterranean Cuisine
# 627                       Italian, Modern Cuisine
# 631                                  Contemporary
# 699               Classic Cuisine, Modern Cuisine
# 806     Country cooking, Cuisine from the Marches
# 891            Cuisine from Abruzzo, Contemporary
# 916                        Creative, Contemporary
# 936          Italian Contemporary, Modern Cuisine
# 982                 Farm to table, Modern Cuisine
# 1074      Mediterranean Cuisine, Seasonal Cuisine
# 1155            Regional Cuisine, Country cooking
# 1217        Modern Cuisine, Mediterranean Cuisine
# 1286                  Farm to table, Contemporary
# 1316                 Modern Cuisine, Contemporary
# 1329                     Sicilian, Modern Cuisine
# 1446                     Modern Cuisine, Creative
# 1540                                   Innovative
# 1544              Mediterranean Cuisine, Ligurian
# 1563               Italian Contemporary, Creative
# 1631     Cuisine from the Marches, Modern Cuisine
# 1636               Contemporary, Seasonal Cuisine
# 1674                       Tuscan, Modern Cuisine
# 1697                         Italian Contemporary
# 1734                                      Seafood
# 1797        Modern Cuisine, Mediterranean Cuisine
# 1809        Italian Contemporary, Country cooking
# 1811              Lombardian, Traditional Cuisine
# 1817                         Italian Contemporary
# 1848                Country cooking, Contemporary
# 1898                 Tuscan, Italian Contemporary
# 1909                                     Creative
# 1952      Seasonal Cuisine, Mediterranean Cuisine
#
#                                             description  \
# 24    The journey to get here – a winding road throu...
# 98    Situated in the city albeit not right in the c...
# 186   This long-established restaurant has been part...
# 211   This typical, elegant Versilian beach club wit...
# 302   Situated within the La Collina dei Ciliegi win...
# 323   Having returned to his native village, owner-c...
# 336   In a tiny rural village, this contemporary, al...
# 416   Situated next to the ruins of the old castle a...
# 446   Despite its lack of awards, this restaurant st...
# 499   Horse-drawn carriages once entered the old cou...
# 627   One of Italy’s long-established restaurants, t...
# 631   A well - run restaurant in a quiet area just o...
# 699   A charming restaurant housed in a skilfully re...
# 806   Situated in the charming historic centre of th...
# 891   Although it takes a while to reach this restau...
# 916   Situated opposite the church of Santa Maria in...
# 936   Situated on the first floor of a building (for...
# 982   At this restaurant in the historic centre, whe...
# 1074  Professional service in a welcoming, modern re...
# 1155  Ronchi Rò is an estate-cum-agriturismo surroun...
# 1217  A quiet restaurant with a relaxed, young and m...
# 1286  Flurin occupies an old medieval tower in Glore...
# 1316  A modern bistro with a cocktail-bar, trendy de...
# 1329  The entrance to this restaurant is typical of ...
# 1446  Modern, tasty and carefully curated cuisine, w...
# 1540  A young, enthusiastic and professional couple ...
# 1544  Situated just beyond the centre of Albenga in ...
# 1563  Housed in the resort of the same name, this el...
# 1631  Situated in the beautiful historic centre of O...
# 1636  A modern, welcoming restaurant whose motto “Tr...
# 1674  This pleasant, warmly decorated restaurant is ...
# 1697  Minimalist decor and clean lines characterise ...
# 1734  The motto of this restaurant is “In step with ...
# 1797  There’s no tasting menu at this restaurant but...
# 1809  Although this restaurant has been in business ...
# 1811  Although the town may not be of major importan...
# 1817  The reopening in 2022 of the Hotel Windsor wit...
# 1848  Le Vie del Borgo is situated in a restored rus...
# 1898  Saporium is the new fine-dining restaurant at ...
# 1909  Enjoying an attractive location in the Nautilu...
# 1952  You’ll be won over by the seasonal Mediterrane...
#
#                                             creditCards  \
# 24         ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 98                       ['Amex', 'Mastercard', 'Visa']
# 186   ['Amex', 'Dinersclub', 'Maestrocard', 'Masterc...
# 211                      ['Amex', 'Mastercard', 'Visa']
# 302                      ['Amex', 'Mastercard', 'Visa']
# 323                              ['Mastercard', 'Visa']
# 336                              ['Mastercard', 'Visa']
# 416        ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 446        ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 499        ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 627       ['Amex', 'Maestrocard', 'Mastercard', 'Visa']
# 631                      ['Amex', 'Mastercard', 'Visa']
# 699   ['Amex', 'Dinersclub', 'Maestrocard', 'Masterc...
# 806   ['Amex', 'Dinersclub', 'Maestrocard', 'Masterc...
# 891                      ['Amex', 'Mastercard', 'Visa']
# 916   ['Amex', 'Unionpay', 'Discover', 'Jcb', 'Maest...
# 936                      ['Amex', 'Mastercard', 'Visa']
# 982        ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 1074      ['Amex', 'Maestrocard', 'Mastercard', 'Visa']
# 1155                                     ['Mastercard']
# 1217       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 1286                             ['Mastercard', 'Visa']
# 1316      ['Amex', 'Maestrocard', 'Mastercard', 'Visa']
# 1329       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 1446                             ['Mastercard', 'Visa']
# 1540              ['Maestrocard', 'Mastercard', 'Visa']
# 1544                             ['Mastercard', 'Visa']
# 1563                     ['Amex', 'Mastercard', 'Visa']
# 1631                     ['Amex', 'Mastercard', 'Visa']
# 1636       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 1674                     ['Amex', 'Mastercard', 'Visa']
# 1697                     ['Amex', 'Mastercard', 'Visa']
# 1734                             ['Mastercard', 'Visa']
# 1797               ['Dinersclub', 'Mastercard', 'Visa']
# 1809                     ['Amex', 'Mastercard', 'Visa']
# 1811                     ['Amex', 'Mastercard', 'Visa']
# 1817                     ['Amex', 'Mastercard', 'Visa']
# 1848                     ['Amex', 'Mastercard', 'Visa']
# 1898                     ['Amex', 'Mastercard', 'Visa']
# 1909       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 1952                     ['Amex', 'Mastercard', 'Visa']
#
#                                      facilitiesServices  \
# 24    ['Car park', 'Interesting wine list', 'Terrace...
# 98    ['Air conditioning', 'Interesting wine list', ...
# 186   ['Air conditioning', 'Counter dining', 'Intere...
# 211   ['Air conditioning', 'Car park', 'Interesting ...
# 302   ['Air conditioning', 'Car park', 'Garden or pa...
# 323                     ['Air conditioning', 'Terrace']
# 336   ['Air conditioning', 'Terrace', 'Wheelchair ac...
# 416   ['Car park', 'Garden or park', 'Terrace', 'Whe...
# 446                                ['Air conditioning']
# 499           ['Air conditioning', 'Wheelchair access']
# 627   ['Air conditioning', 'Car park', 'Garden or pa...
# 631   ['Air conditioning', 'Interesting wine list', ...
# 699   ['Interesting wine list', 'Restaurant offering...
# 806                                         ['Terrace']
# 891   ['Air conditioning', 'Car park', 'Great view',...
# 916   ['Air conditioning', 'Interesting wine list', ...
# 936   ['Air conditioning', 'Restaurant offering vege...
# 982   ['Air conditioning', 'Terrace', 'Wheelchair ac...
# 1074                               ['Air conditioning']
# 1155  ['Car park', 'Garden or park', 'Great view', '...
# 1217  ['Air conditioning', 'Terrace', 'Wheelchair ac...
# 1286                    ['Air conditioning', 'Terrace']
# 1316  ['Air conditioning', 'Terrace', 'Wheelchair ac...
# 1329  ['Air conditioning', 'Restaurant offering vege...
# 1446                               ['Air conditioning']
# 1540  ['Air conditioning', 'Terrace', 'Wheelchair ac...
# 1544      ['Air conditioning', 'Great view', 'Terrace']
# 1563  ['Air conditioning', 'Car park', 'Interesting ...
# 1631                    ['Air conditioning', 'Terrace']
# 1636                   ['Air conditioning', 'Car park']
# 1674  ['Air conditioning', 'Terrace', 'Wheelchair ac...
# 1697  ['Air conditioning', 'Restaurant offering vege...
# 1734  ['Air conditioning', 'Terrace', 'Wheelchair ac...
# 1797          ['Air conditioning', 'Wheelchair access']
# 1809  ['Air conditioning', 'Garden or park', 'Intere...
# 1811  ['Air conditioning', 'Car park', 'Wheelchair a...
# 1817  ['Air conditioning', 'Great view', 'Terrace', ...
# 1848                                        ['Terrace']
# 1898  ['Air conditioning', 'Car park', 'Garden or pa...
# 1909  ['Air conditioning', 'Car park', 'Interesting ...
# 1952      ['Air conditioning', 'Great view', 'Terrace']
#
#                                             phoneNumber  \
# 24                                      +39 0444 687709
# 98                                     +39 010 595 5205
# 186                                       +39 02 416886
# 211                                      +39 0584 20187
# 302                                    +39 045 981 4900
# 323                                     +39 0874 799230
# 336                                      +39 030 941149
# 416                                     +39 0432 810466
# 446   https://www.theforkmanager.com/partnership-the...
# 499                                   +39 055 2716 3770
# 627                                    +39 030 914 3361
# 631                                    +39 011 649 9238
# 699   https://www.theforkmanager.com/partnership-the...
# 806                                     +39 0735 588644
# 891                                      +39 085 845219
# 916                                    +39 06 6813 9022
# 936                                    +39 091 811 3775
# 982                                    +39 085 201 1844
# 1074                                     +39 011 836145
# 1155                                   +39 371 429 5269
# 1217                                   +39 011 020 1580
# 1286                                    +39 0473 428136
# 1316                                   +39 02 4775 5505
# 1329                                  +39 095 1693 1045
# 1446  https://www.theforkmanager.com/partnership-the...
# 1540                                   +39 349 068 3973
# 1544                                    +39 0182 544556
# 1563                                   +39 030 715 7254
# 1631                                    +39 0736 889920
# 1636                                   +39 06 4555 7597
# 1674  https://www.theforkmanager.com/partnership-the...
# 1697                                   +39 06 6813 6310
# 1734                                     +39 035 511213
# 1797                                   +39 080 403 8320
# 1809                                    +39 0439 788019
# 1811  https://www.theforkmanager.com/partnership-the...
# 1817                                    +39 0182 038029
# 1848                                   +39 346 624 9050
# 1898                                    +39 0577 751222
# 1909                                    +39 06 562 2778
# 1952                                  +39 081 1904 1517
#
#                                                website  \
# 24                       https://www.casindelgamba.it/
# 98          https://www.ristorantesangiorgiogenova.it/
# 186   https://www.aimoenadia.com/il-luogo-aimo-e-nadia
# 211                 https://vestafiorichiari.com/mare/
# 302                      https://www.cadelmoro.wine/it
# 323                     https://contrastoristorante.it
# 336                          https://ristorantesaur.it
# 416                       http://sanmichele.restaurant
# 446                               tel:+39 328 905 4831
# 499           https://www.wintergardenflorence.com/it/
# 627              https://www.ristorante-esplanade.com/
# 631                  https://www.ristorantelavalle.it/
# 699                                tel:+39 0473 920927
# 806               https://www.degusteriadelgigante.it/
# 891                         https://www.labandiera.it/
# 916                         https://www.piperoroma.it/
# 936               http://www.ristorantesecondotempo.it
# 982                             http://www.aprudia.com
# 1074             https://www.ristorantepiccololord.it/
# 1155                           https://www.ronchiro.it
# 1217                            https://vadoarazzo.it/
# 1286                             https://www.flurin.it
# 1316                     https://www.quadribistrot.it/
# 1329               https://www.materiaspaziocucina.it/
# 1446                              tel:+39 342 359 9215
# 1540                      https://www.abitatproject.it
# 1544                https://www.ristorantebabette.net/
# 1563                        https://www.cappuccini.it/
# 1631                     https://www.osteriaophis.com/
# 1636                       http://ristorantesintesi.it
# 1674                               tel:+39 0587 757374
# 1697                     https://www.retro-bottega.com
# 1734                        https://www.ristofante.it/
# 1797                           http://www.radimare.com
# 1809                    https://www.locandasolagna.it/
# 1811                             tel:+39 0372 166 4229
# 1817                          http://www.thewindsor.it
# 1848           https://www.leviedelborgoguesthouse.it/
# 1898    http://www.saporium.com/it/borgo-santo.pietro/
# 1909                 https://www.ristoranteiltino.com/
# 1952                  http://www.domo20.com/restaurant
#
#                                   processed_description
# 24    journey get wind road wood hill may challeng t...
# 98    situat citi albeit right centr san giorgio typ...
# 186   longestablish restaur part milanes culinari sc...
# 211   typic eleg versilian beach club openplan feel ...
# 302   situat within la collina dei ciliegi wine esta...
# 323   return nativ villag ownerchef lucio testa open...
# 336   tini rural villag contemporari almost minimali...
# 416   situat next ruin old castl small church san mi...
# 446   despit lack award restaur stand qualiti cuisin...
# 499   horsedrawn carriag enter old courtyard st regi...
# 627   one itali longestablish restaur esplanad proud...
# 631   well run restaur quiet area outsid villag owne...
# 699   charm restaur hous skil restor old farm everyt...
# 806   situat charm histor centr upper part town righ...
# 891   although take reach restaur first open definit...
# 916   situat opposit church santa maria vallicella k...
# 936   situat first floor build formerli home apart o...
# 982   restaur histor centr vault brick ceil provid s...
# 1074  profession servic welcom modern restaur run yo...
# 1155  ronchi rò estatecumagriturismo surround verdan...
# 1217  quiet restaur relax young modern feel serv con...
# 1286  flurin occupi old mediev tower glorenza small ...
# 1316  modern bistro cocktailbar trendi decor soft li...
# 1329  entranc restaur typic old residentialstyl buil...
# 1446  modern tasti care curat cuisin prepar use best...
# 1540  young enthusiast profession coupl taken rein m...
# 1544  situat beyond centr albenga beauti locat right...
# 1563  hous resort name eleg restaur full histor char...
# 1631  situat beauti histor centr offida restaur bric...
# 1636  modern welcom restaur whose motto tradit innov...
# 1674  pleasant warmli decor restaur run passion enth...
# 1697  minimalist decor clean line characteris restau...
# 1734  motto restaur step time yet inspir tradit cuis...
# 1797  there tast menu restaur instead tempt la cart ...
# 1809  although restaur busi sinc feel much modern th...
# 1811  although town may major import cuisin serv mod...
# 1817  reopen hotel windsor romant vintag decor real ...
# 1848  le vie del borgo situat restor rustic build si...
# 1898  saporium new finedin restaur superb relai borg...
# 1909  enjoy attract locat nautilu marina overlook ti...
# 1952  youll season mediterranean cuisin creat young ...

# %% [markdown]
# ## 2.2 Ranked Search Engine with TF-IDF and Cosine Similarity
#
# This search engine ranks the top-k restaurants based on their **similarity scores** with the user query using **TF-IDF** and **Cosine Similarity**.
#
# ### **Process**:
#
# 1. **TF-IDF Calculation**:
#    - **TF-IDF** measures term importance within a restaurant description and across the dataset.
#    - The formula is:
#
#    \[
#    \text{TF-IDF}(term, document) = \text{TF}(term, document) \times \text{IDF}(term)
#    \]
#
#    - **TF** is the frequency of the term in the document.
#    - **IDF** reduces the weight of common terms across all descriptions.
#
# 2. **Updated Inverted Index**:
#    - The inverted index is updated to map each term (`term_id`) to a list of tuples containing:
#      - The restaurant's document ID.
#      - The corresponding **TF-IDF score**.
#
#    Example:
#    ```python
#    {
#      "term_id_1": [(doc_1, tfIdf_1), (doc_2, tfIdf_2)],
#      "term_id_2": [(doc_3, tfIdf_3), (doc_4, tfIdf_4)]
#    }

# %% [markdown]
# ### 2.2.1 Inverted Index with TF-IDF Scores

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer

#TF-IDF scores
def build_inverted_index(data):
    # Vectorize descriptions using TF-IDF
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(data['description'])
    terms = vectorizer.get_feature_names_out()

    # inverted index with TF-IDF scores
    inverted_index = defaultdict(list)
    for doc_id, row in enumerate(tfidf_matrix):
        for term_id, tfidf_score in zip(row.indices, row.data):
            term = terms[term_id]
            inverted_index[term].append((doc_id, tfidf_score))

    return inverted_index, vectorizer

# Generate the inverted index
inverted_index, vectorizer = build_inverted_index(data)

# %% [markdown]
# 2.2.2

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np



# TF-IDF vectors for each restaurant description
def preprocess_data(data):
    # Vectorize descriptions
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(data['description'])
    return tfidf_matrix, vectorizer

# Ranked query using TF-IDF and Cosine Similarity
def execute_ranked_query(query, data, tfidf_matrix, vectorizer, top_k=5):
    #Transform the query using the same vectorizer
    query_vector = vectorizer.transform([query])

    # Calculate cosine similarity between the query and all documents
    similarity_scores = cosine_similarity(query_vector, tfidf_matrix).flatten()

    # Get indices of documents with non-zero similarity, sorted by score
    ranked_indices = np.argsort(similarity_scores)[::-1]
    ranked_indices = [idx for idx in ranked_indices if similarity_scores[idx] > 0]

    #Top-k results
    top_k_indices = ranked_indices[:top_k] if len(ranked_indices) >= top_k else ranked_indices

    results = data.iloc[top_k_indices][["restaurantName", "address", "description", "website"]].copy()
    results['similarity_score'] = similarity_scores[top_k_indices]
    results = results.reset_index(drop=True)
    return results

tfidf_matrix, vectorizer = preprocess_data(data)


query2 = 'modern seasonal cuisine'
top_k = 5  # Number of results to return
result2 = execute_ranked_query(query2, data, tfidf_matrix, vectorizer, top_k=top_k)

print(result2)
# Out:
#   restaurantName                                   address  \
# 0           Saur                      via Filippo Turati 8
# 1          Razzo                     via Andrea Doria 17/f
# 2       La Botte                  via Giuseppe Garibaldi 8
# 3   Piccolo Lord               corso San Maurizio 69 bis/g
# 4       La Valle  via Umberto I 25, località Valle Sauglio
#
#                                          description  \
# 0  In a tiny rural village, this contemporary, al...
# 1  A quiet restaurant with a relaxed, young and m...
# 2  A modern and welcoming contemporary bistro sit...
# 3  Professional service in a welcoming, modern re...
# 4  A well - run restaurant in a quiet area just o...
#
#                                  website  similarity_score
# 0              https://ristorantesaur.it          0.311022
# 1                 https://vadoarazzo.it/          0.264815
# 2   http://www.trattorialabottestresa.it          0.246574
# 3  https://www.ristorantepiccololord.it/          0.224096
# 4      https://www.ristorantelavalle.it/          0.217656

# %% [markdown]
# #### **Comparison and Evaluation**:
# - The **Conjunctive Search Engine** offers precise, narrow results where all query terms must appear, making it highly accurate for specific searches.
# - The **Ranked Search Engine** provides a broader range of results sorted by relevance, making it more flexible for general queries.
#
# #### **Conclusion**:
# This two-pronged search engine approach enhances user experience by catering to both specific and general queries. The conjunctive engine ensures accurate filtering, while the ranked engine offers a sorted list of the most relevant options, leveraging TF-IDF scoring to highlight the best matches.

# %% [markdown]
# #**[3] Define a New Score!**

# %% [markdown]
# To improve the relevance and diversity of search results, we will introduce a custom ranking metric that accounts for multiple restaurant attributes alongside the query's textual similarity.
#
# **Approach:**
#
# 1. **User Query Input**:
#    Begin with the user-provided query text to retrieve relevant restaurants using the search engine developed in Step 2.1.
#
# 2. **Incorporate Multi-Attribute Scoring**:
#    Move beyond the basic description similarity by considering other attributes such as:
#    - **Cuisine Type**: Prioritize matches with cuisine preferences.
#    - **Facilities and Services**: Boost scores for restaurants offering sought-after amenities.
#    - **Price Range**: Tailor scoring to favor budget-friendly or premium options, based on user preference.
#    - **Description Match**: Retain weightage for TF-IDF-based textual relevance.
#
# 3. **Efficient Ranking with Heap**:
#    Leverage a heap data structure to dynamically maintain the top-k restaurants as they are scored.
#
# **New Scoring Function**:
#
# The scoring function will evaluate restaurants on multiple criteria and assign a composite score:
#    - **Description Similarity**: A weighted score from the TF-IDF vector similarity.
#    - **Cuisine Preference**: Add points for matching the cuisine type.
#    - **Facilities Match**: Increment the score for each amenity in the user's query.
#    - **Affordability Factor**: Assign additional weight to restaurants in the user's preferred price range.
#
# **Implementation Steps**:
# 1. Preprocess and tokenize the query to identify keywords related to descriptions, facilities, and cuisine types.
# 2. Compute the description similarity using the TF-IDF vector and cosine similarity from Step 2.1.
# 3. Evaluate cuisine and facilities matches by cross-referencing attributes.
# 4. Integrate all scores into a single composite score using predefined weights.
# 5. Use a heap to efficiently maintain the top-k results.
#
# **Output**:
#
# The final output will include:
#    - **restaurantName**: The name of the restaurant.
#    - **address**: Location details for user convenience.
#    - **description**: A brief overview of the restaurant.
#    - **website**: Direct link for further exploration.
#    - **Custom Metric Score**: The computed score based on the new ranking function.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import heapq

# Custom scoring function
def custom_score(row, query_terms, vectorizer, description_tfidf, cuisine_weight=1.0, facilities_weight=1.0, price_weight=1.0):
    # Description similarity score using TF-IDF and Cosine Similarity
    query_vector = vectorizer.transform([" ".join(query_terms)])
    desc_vector = description_tfidf[row.name]
    description_score = cosine_similarity(query_vector, desc_vector).flatten()[0]

    # Cuisine match score
    cuisine_score = sum([cuisine_weight for cuisine in row['cuisineType'].split(', ') if cuisine.lower() in query_terms])

    # Facilities match score
    facilities_score = sum([facilities_weight for facility in row['facilitiesServices'] if facility.lower() in query_terms])

    # Price range score (based on € range, prioritizing lower prices)
    price_range = len(row['priceRange'])  # € -> low, €€€€ -> high
    price_score = max(5 - price_range, 0) * price_weight  # prioritize lower price if desired

    #Total score
    total_score = (description_score * 2) + cuisine_score + facilities_score + price_score
    return total_score

# %%
def rank_conjunctive_results(query, subset_data, vectorizer, description_tfidf, top_k=10):
    # Preprocess the query terms
    processed_query = preprocess_text(query)
    query_terms = set(processed_query.split())

    # Score each restaurant in the conjunctive results
    scored_restaurants = []
    for idx, row in subset_data.iterrows():
        score = custom_score(row, query_terms, vectorizer, description_tfidf)
        scored_restaurants.append((score, idx))

    #Heap to get the top-k restaurants based on the custom score
    top_k_restaurants = heapq.nlargest(top_k, scored_restaurants, key=lambda x: x[0])
    top_k_indices = [idx for _, idx in top_k_restaurants]

    #Top-k results and sort by custom score
    results = subset_data.loc[top_k_indices].copy()
    results['custom_score'] = [score for score, _ in top_k_restaurants]
    results = results.sort_values(by='custom_score', ascending=False).reset_index(drop=True)

    return results

query3='modern seasonal cuisine'

conjunctivs_results = execute_query(query3, data)

sorted_results = rank_conjunctive_results(query1, conjunctivs_results, vectorizer, tfidf_matrix, top_k=10)
print(sorted_results[["restaurantName", "address", "description","website","custom_score"]])
# Out:
#             restaurantName                         address  \
# 0  Osteria del Miglio 2.10                  via Patrioti 2
# 1            Osteria Ophis       corso Serpente Aureo 54/b
# 2          Osteria Taviani  piazza Vittorio Emanuele II 28
# 3                     Saur            via Filippo Turati 8
# 4                    Razzo           via Andrea Doria 17/f
# 5             Piccolo Lord     corso San Maurizio 69 bis/g
# 6                     Mima                via Madonnelle 9
# 7          Locanda Solagna            piazza I  Novembre 2
# 8                Chichibio         via Guglielmo Marconi 1
# 9              San Michele      via Castello di Fagagna 33
#
#                                          description  \
# 0  Although the town may not be of major importan...
# 1  Situated in the beautiful historic centre of O...
# 2  This pleasant, warmly decorated restaurant is ...
# 3  In a tiny rural village, this contemporary, al...
# 4  A quiet restaurant with a relaxed, young and m...
# 5  Professional service in a welcoming, modern re...
# 6  You’ll be won over by the seasonal Mediterrane...
# 7  Although this restaurant has been in business ...
# 8  Despite its lack of awards, this restaurant st...
# 9  Situated next to the ruins of the old castle a...
#
#                                  website  custom_score
# 0                  tel:+39 0372 166 4229      4.077801
# 1          https://www.osteriaophis.com/      3.357630
# 2                    tel:+39 0587 757374      3.320099
# 3              https://ristorantesaur.it      3.143060
# 4                 https://vadoarazzo.it/      3.121806
# 5  https://www.ristorantepiccololord.it/      3.103077
# 6       http://www.domo20.com/restaurant      3.082628
# 7         https://www.locandasolagna.it/      3.080183
# 8                   tel:+39 328 905 4831      3.079253
# 9           http://sanmichele.restaurant      3.068248

# %% [markdown]
# ## Analysis of Restaurant Order Changes
#
# ### Key Adjustments and Benefits:
# - The custom scoring metric prioritizes restaurants with **matching cuisine types** and **desired facilities** from the user's query.
#   - For example, a query like *"modern seasonal cuisine with a garden"* gives higher priority to restaurants such as **Winter Garden**, which offers modern cuisine and garden seating.
# - **Middle-ranked restaurants** like **La Bandiera** and **Ape Vino** were ranked higher due to diverse services (e.g., terrace seating, seasonal offerings) and specific cuisines matching user preferences.
# - Restaurants that lacked key features (e.g., garden seating) were **lower-ranked**, even if their descriptions were textually similar.
#
# ### Methodology and Results:
# 1. **Custom Metric Implementation**:
#    - Textual relevance (TF-IDF) was combined with a custom scoring metric that considers:
#      - Facilities like garden, terrace seating.
#      - Cuisine type and affordability.
# 2. **Impact of Changes**:
#    - Conjunctive filtering and custom scoring led to a more **personalized recommendation list**.
#    - Top restaurants like **Osteria del Miglio 2.10** balanced textual relevance with user preferences.
# 3. **Example Results**:
#    - Example query: *"modern seasonal cuisine"*
#    - Top-ranked results included:
#      - Osteria del Miglio 2.10
#      - Osteria Ophis
#      - Osteria Taviani
#
# ### Conclusion:
# - The custom scoring function effectively **reshaped the ranking order** by integrating user preferences such as cuisine type, facilities, and affordability.
# - This enhanced ranking quality by providing recommendations that align closely with user expectations.
